# %%
import json
import numpy as np
from metaspace.sm_annotation_utils import SMInstance # pip install metaspace2020
import os

# %%
Here the directory that need to be created: let say the main path is ./DS/
DS/MSI
DS/MSI/raw_data # DS/MSI/raw_data/ can contain as many directory as msi data, inside each of those msi data directory we can find the ibd and imzml of the corresponding MSI
DS/MSI/centroid_data # DS/MSI/centroid_data/ contain as many directory as preprocessing parameters file run, those directories havve the name of the preprocessing param file witthou .json. Inside the preprocessing param dir, there are different dir with name of the MSI name, each of those directory contain spec and graph .npy object for each pixel of the MSI.   

DS/parameter
DS/parameters/pre_processing # DS/parameters/pre_processing/ contains the preprocessing parameters .json file containing information of generating centroid_data from one or multiple raw_data
DS/parameters/network # DS/parameters/network/ contains the RGCN network parameters .json file containing information regarding the network learning. 


DS/models
DS/models/GCN # DS/models/GCN/ contains the model.pth.tar model objectof the best model with name of the preprocessing parameters and network parameters file concatenate
DS/models/CAM_output # DS/models/CAM_output/ contains directories that contain output of CAM model for each pixel of an image.


The command line of the RGCn model create automatically DS/models,DS/models/GCN,DS/models/CAM_output and subdirectories.
However we need to create the following directory manually. 

DS/MSI
DS/MSI/raw_data 
DS/MSI/centroid_data 
DS/parameter
DS/parameters/pre_processing 
DS/parameters/network

can you make a script to create those ?

# %%
import os
import shutil

# Base path for the DS structure
#base_path = "./DS"
base_path = "/media/USB2/Massconvnet_data/"

# Directories to create
directories = [
    "MSI",
    "MSI/raw_data",
    "MSI/centroid_data",
    "parameters",
    "parameters/pre_processing",
    "parameters/network",
    "mass_diff",
    "Annot_table"
]

# Create each directory
for dir_name in directories:
    full_path = os.path.join(base_path, dir_name)
    os.makedirs(full_path, exist_ok=True)
    print(f"Created directory: {full_path}")

# Move the mass_diff.csv file
source_file = "./data/mass_diff.csv"
destination_file = os.path.join(base_path, "mass_diff", "mass_diff.csv")

if os.path.exists(source_file):
    shutil.move(source_file, destination_file)
    print(f"Moved mass_diff.csv to: {destination_file}")
else:
    print(f"⚠️ File not found: {source_file}. Please make sure it exists before running this script.")
# Out:
# Created directory: /media/USB2/Massconvnet_data/MSI
# Created directory: /media/USB2/Massconvnet_data/MSI/raw_data
# Created directory: /media/USB2/Massconvnet_data/MSI/centroid_data
# Created directory: /media/USB2/Massconvnet_data/parameters
# Created directory: /media/USB2/Massconvnet_data/parameters/pre_processing
# Created directory: /media/USB2/Massconvnet_data/parameters/network
# Created directory: /media/USB2/Massconvnet_data/mass_diff
# Created directory: /media/USB2/Massconvnet_data/Annot_table
# Moved mass_diff.csv to: /media/USB2/Massconvnet_data/mass_diff/mass_diff.csv

# %%
Then ,We need to move the mass_diff file from the data directory of the github page to the newly created DS/mass_diff/ fodler

# %%
Then, the user to create in /media/USB2/Massconvnet_data/MSI/raw_data one directory per MSI data and palce the ibd and imzml file in the newly created dir

# %%
Then, we need to generate an Annot_table csv file for a experiemnt, this table must at least the following 7 columns
"MSI name"	"MSI pixel id"	"Annotations"	"Crd X"	"Crd Y"	"origianl MSI pixel id"	"train"
Each row correspond to pixel/or spectrum from an MSI in MSI/raw_data. 
This annot_table dataframe will specify to the command line Centroid_from_imzml.py which pixel to retrieve from raw_data dir  to transform the ranw pixel spectrum into a centroid spectrum and a graph
But it will also specify the network the class of each pixel and if the pixel must be used for training for testing 


Below we specify each column: 
"MSI name" -> correspond to the name of the MSI in MSI/raw_data (string)
"MSI pixel id" -> correspond to pixel id of the spectrum once centroided (int)
"Annotations" -> correspond to the class of the pixel for the RGCN classification (int)
"Crd X" and "Crd Y" -> are the positions of the pixel in a 2 D space (int)
"origianl MSI pixel id" -> The original piel ID in the MSI imzml (int)
"train" -> a binary to tell the network if the pixel should be use for training or testing (bool)

# %%
#dataset folder name: DS
# create a folder MSI: mkdir DS/MSI
# mkdir DS/MSI/raw_data
# mkdir DS/MSI/centroid_data

# create parameters folder: mkdir DS_1/parameters
# create parameters folder: mkdir DS_1/parameters/pre_processing

# %%
metaspace_im = ["2020-12-09_02h41m05s","2021-08-16_23h19m04s" ,"2020-01-17_17h36m25s","2019-12-16_15h22m13s"]

folder_msi = "/media/USB/DL_MASS/Dataset/DS/MSI/raw_data/"
sm = SMInstance()
for dsid in metaspace_im:

    ds = sm.dataset(id=dsid)
    os.mkdir(folder_msi + ds.name)
    ds.download_to_dir(folder_msi + ds.name)
# Out:
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv/#8.imzML
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv/#8.ibd
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/20210814_jl_lungmap_d281_8a3_pos_slide2_7b/20210814_jl_lungmap_d281_8a3_pos_slide2_7b.imzML
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/20210814_jl_lungmap_d281_8a3_pos_slide2_7b/20210814_jl_lungmap_d281_8a3_pos_slide2_7b.ibd
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/16012020_DN_VS_RW10S2_722_exp18_100_143x461_30/16012020_DN_VS_RW10S2_722_exp18_100_143x461_30.imzML
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/16012020_DN_VS_RW10S2_722_exp18_100_143x461_30/16012020_DN_VS_RW10S2_722_exp18_100_143x461_30.ibd
# Wrote /media/USB/DL_MASS/Dataset/DS/MSI/raw_data/2019-12-12_DDN_SCoelicolor_100_180x317_30/2019-12-12_DDN_SCoelicolor_100_180x317_30.imzML
# ...

# %%
import os
import json
import numpy as np

# Define base folder
#folder_path = "./DS/"
folder_path = "/media/USB2/Massconvnet_data/"

# Load mass_diff values
mass_diff_path = os.path.join(folder_path, "mass_diff", "mass_diff.csv")
mass_diff = np.genfromtxt(mass_diff_path)
mass_diff = mass_diff.tolist()

# Build dictionary
param_dict = {
    "max_peaks": 2000,
    "mass_diff": mass_diff,
    "tolerance": 0.005,
    "mass range": [200, 2200],
    "msi_dir": os.path.join(folder_path, "MSI", "raw_data") + "/",  # Ensure trailing slash
    "output_dir": os.path.join(folder_path, "MSI", "centroid_data") + "/",
    "file_type": "imzML",
    "annot_table": os.path.join(folder_path, "Annot_table" ,"pseudomnas_control_annottable.csv")  # Adjust if name changes
}

# Save JSON
output_path = os.path.join(folder_path, "parameters", "pre_processing", "param_spaceM_tol05.json")
os.makedirs(os.path.dirname(output_path), exist_ok=True)

with open(output_path, "w") as f:
    json.dump(param_dict, f, indent=4)

print(f"✅ Preprocessing parameter file saved to: {output_path}")
# Out:
# ✅ Preprocessing parameter file saved to: /media/USB2/Massconvnet_data/parameters/pre_processing/param_pseudo_tol05.json

# %%
import os
import json
import numpy as np

# Define base folder
#folder_path = "./DS/"
folder_path = "/media/USB2/Massconvnet_data/"

# Load mass_diff values
mass_diff_path = os.path.join(folder_path, "mass_diff", "mass_diff.csv")
mass_diff = np.genfromtxt(mass_diff_path)
mass_diff = mass_diff.tolist()

# Build dictionary
param_dict = {
    "max_peaks": 2000,
    "mass_diff": mass_diff,
    "tolerance": 0.001,
    "mass range": [200, 1600],
    "msi_dir": os.path.join(folder_path, "MSI", "raw_data") + "/",  # Ensure trailing slash
    "output_dir": os.path.join(folder_path, "MSI", "centroid_data") + "/",
    "file_type": "imzML",
    "annot_table": os.path.join(folder_path, "Annot_table" ,"Annot_table_interactionfer_centroid.csv")  # Adjust if name changes
}

# Save JSON
output_path = os.path.join(folder_path, "parameters", "pre_processing", "param_interactionfer_tol01.json")
os.makedirs(os.path.dirname(output_path), exist_ok=True)

with open(output_path, "w") as f:
    json.dump(param_dict, f, indent=4)

print(f"✅ Preprocessing parameter file saved to: {output_path}")
# Out:
# ✅ Preprocessing parameter file saved to: /media/USB2/Massconvnet_data/parameters/pre_processing/param_interactionfer_tol01.json

# %%
import subprocess
import os


# Define paths
github_dir ="/home/user/Massconvnet/Massconvnet_2025/"  # Corrected from your typo "/githuh"
folder_path = "/media/USB2/Massconvnet_data/"

# Script and input parameter paths
script_path = os.path.join(github_dir, "MSI_preprocessing", "Centroid_from_imzml.py")
param_file = os.path.join(folder_path, "parameters", "pre_processing", "param_spaceM_tol01.json")

# Run the script using subprocess (in the background with nohup)
command = f"nohup python {script_path} -i {param_file} &"
subprocess.run(command, shell=True)

print("✅ Launched Centroid_from_imzml.py as background process with nohup.")
# Out:
# ✅ Launched Centroid_from_imzml.py as background process with nohup.

# %%
import os
import json
import numpy as np

# Define base folder
#folder_path = "./DS/"
folder_path = "/media/USB2/Massconvnet_data/"

# Load mass_diff values
mass_diff = [15.97394, 21.98194, 37.95588,1.0033,2.0067,2.0043,14.01565,28.03130,56.06260,2.01565,15.99491,13.97926,189.04259]

# Build dictionary
param_dict = {
    "max_peaks": 2000,
    "mass_diff": mass_diff,
    "tolerance": 0.003,
    "mass range": [200, 2200],
    "msi_dir": os.path.join(folder_path, "MSI", "raw_data") + "/",  # Ensure trailing slash
    "output_dir": os.path.join(folder_path, "MSI", "centroid_data") + "/",
    "file_type": "imzML",
    "annot_table": os.path.join(folder_path, "Annot_table" ,"pseudomnas_control_annottable.csv")  # Adjust if name changes
}

# Save JSON
output_path = os.path.join(folder_path, "parameters", "pre_processing", "param_pseudo_tol03_reducenet.json")
os.makedirs(os.path.dirname(output_path), exist_ok=True)

with open(output_path, "w") as f:
    json.dump(param_dict, f, indent=4)

print(f"✅ Preprocessing parameter file saved to: {output_path}")
# Out:
# ✅ Preprocessing parameter file saved to: /media/USB2/Massconvnet_data/parameters/pre_processing/param_pseudo_tol03_reducenet.json

# %%
import subprocess
import os
import time

# Define paths
github_dir = "/github"  # Adjust this if needed
folder_path = "./DS"

script_path = os.path.join(github_dir, "MSI_preprocessing", "Centroid_from_imzml.py")
param_file = os.path.join(folder_path, "parameters", "pre_processing", "param_1.json")

# Start timer
start_time = time.time()

# Run the script and wait for it to complete
print("🚀 Running Centroid_from_imzml.py ...")
result = subprocess.run(["python", script_path, "-i", param_file])

# End timer
end_time = time.time()
elapsed = end_time - start_time

# Show result
if result.returncode == 0:
    print(f"✅ Completed successfully in {elapsed:.2f} seconds.")
else:
    print(f"❌ Script exited with code {result.returncode} after {elapsed:.2f} seconds.")

# %%
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i '/media/USB2/Massconvnet_data/parameters/pre_processing/param_pseudo_tol03_reducenet.json' &
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i '/media/USB2/Massconvnet_data/parameters/pre_processing/param_cellobiose_tol03_reducenet.json' &
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i '/media/USB2/Massconvnet_data/parameters/pre_processing/param_spaceM_tol03_reducenet.json' &
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i '/media/USB2/Massconvnet_data/parameters/pre_processing/param_interactionfer_tol03_reducenet.json' &

# %%
## Datacube preprossing

# %%
nohup python /home/user/msi_database_search/mean_spectrum_msi_2.py -i "/mnt/partagenfs/mslab5/Users/Raphael/SpaceM/F4/20171107_F4_DHBpos_p70_s50.imzML" -o1 "/media/USB2/DL_MASS/SpaceM/F4.mean" -p 50 &
nohup python create_msi_da.py -i "/mnt/partagenfs/mslab5/Users/Raphael/SpaceM/F1/20171107_F1_DHBpos_p70_s50.imzML" -i2 "/media/USB2/DL_MASS/SpaceM/F1_3_U1_3.peaks" -tol 0.01 -o1 "/media/USB2/DL_MASS/SpaceM/F1" &

# %%
from scipy import interpolate
from scipy.signal import find_peaks

def peak_picking(files,max_peaks):
    
    ints_n = 0
    
    min_mz = 0
    max_mz = 0 
    
    for f in files:
        ms = np.load(f)
        mzs = ms[0,]
        
        if min_mz > np.min(mzs):
            min_mz = np.min(mzs)
            
        if max_mz < np.max(mzs):
            max_mz = np.max(mzs)    
    
    for f in files:
        ms = np.load(f)

        mzs = ms[0,]
        ints = ms[1,]

        mzs_n = np.arange(min_mz,max_mz, 0.0001)
        
        f = interpolate.interp1d(mzs , ints,fill_value="extrapolate")
        ints_n = ints_n + f(mzs_n)
    
    peaks, _ = find_peaks(ints_n,distance=100)
    instensity_mean = ints_n[peaks]
    mz_peaks = mzs_n[peaks]

    peaks = peaks[np.argsort(ints_n[peaks])[::-1][:max_peaks]]

    return(np.sort(mzs_n[peaks]))

mass = peak_picking(["/media/USB2/DL_MASS/SpaceM/F1.mean.npy","/media/USB2/DL_MASS/SpaceM/F3.mean.npy"])
np.savetxt("/media/USB2/DL_MASS/SpaceM/F1_3.peaks", mass, delimiter=",")

# %%
import numpy as np
from numpy import genfromtxt
import pandas as pd


def check_mass_database(experimental_mass, database_mass, tolerance):
    if database_mass != 0:
        return abs((experimental_mass - database_mass)) <= tolerance
    
    
def binarySearch_tol(arr, l, r, x, tolerance): 
  
    while l <= r: 
  
        mid = l + (r - l)//2; 
          
        # Check if x is present at mid 
        if check_mass_database(x,arr[mid],tolerance): 
            # check the mass around 
            itpos = mid +1
            itneg = mid -1
            index = []
            index.append(mid)
            if( itpos < len(arr)):
                while check_mass_database(x,arr[itpos],tolerance) and itpos < len(arr):
                    index.append(itpos)
                    itpos += 1 
            if( itneg > 0): 
                while check_mass_database(x,arr[itneg],tolerance) and itneg > 0:
                    index.append(itneg)
                    itneg -= 1     
            return index 
  
        # If x is greater, ignore left half 
        elif arr[mid] < x: 
            l = mid + 1
  
        # If x is smaller, ignore right half 
        else: 
            r = mid - 1
      
    # If we reach here, then the element 
    # was not present 
    return -1

def align_peaks(peaks_mz,intensities,database_exactmass, tolerance): 
    pixel_new_vec = np.zeros(np.size(database_exactmass,0))
    for i in range(0,np.size(peaks_mz,0)):
        exp_peak = peaks_mz[i]
        # append the maximum mass possible to avoid going over
        vec_ind = binarySearch_tol(np.append(database_exactmass,np.max(database_exactmass)+1), 0, len(database_exactmass)-1, exp_peak,tolerance)
        if vec_ind != -1:
            if len(vec_ind) > 1:
                for j in range(0,np.size(vec_ind,0)):
                    if intensities[i] > pixel_new_vec[vec_ind[j]]:
                        pixel_new_vec[vec_ind[j]] = intensities[i]
                        
            if len(vec_ind) == 1:
                if intensities[i] > pixel_new_vec[vec_ind]:
                    pixel_new_vec[vec_ind] = intensities[i]
                
    return(pixel_new_vec)

def create_datacube(file,peaks_file,df,tolerance):
    
    msi_mz = genfromtxt(peaks_file, delimiter=' ')
    database_exactmass = np.sort(msi_mz)
    
    msi = np.zeros((np.size(database_exactmass),np.shape(df)[0]))

    i = 0 
    for index, row in df.iterrows():
        
        print(str(row['MSI pixel id']),row['train'])
        path = file + row['MSI name'] +"/spec_" + str(row['MSI pixel id']) + ".npy"
        spec = np.load(path)
        
        mode = row['train']
        
        mzs = spec[:,0]
        intensities = spec[:,2]
        
        peaks_mz = mzs
        vec_int = intensities
        pixel_new_vec = align_peaks(peaks_mz,vec_int,database_exactmass, tolerance)
        msi[:,i] = pixel_new_vec
        i += 1
    
    
    return(msi)

#peaks_file = '/media/USB2/DL_MASS/Dataset/DS/peaks_all'

peaks_file = "/media/USB2/DL_MASS/DS3/trainDSreduce.peaks"
#peaks_file = "/media/USB2/DL_MASS/SpaceM/F1_3_U1_3.peaks"

tolerance = 0.001
df = pd.read_csv("/media/USB2/DL_MASS/DS3/Annot_table_reduce.csv",sep=",", header=0)

f = "/media/USB2/DL_MASS/DS3/MSI/centroid_data/param_1reduce/"

msi = create_datacube(f,peaks_file,df,tolerance)
np.save(f+"msi",msi)

# %%
import os
import numpy as np
import pandas as pd

# dataloader
def bin_ms(spec,mass_range,tol):
    
    vec_bin = np.arange(mass_range[0],mass_range[1],tol)
    bin_spec = np.zeros((len(vec_bin)))
    
    for i in range(0,len(vec_bin)):
        bin_i = vec_bin[i]
        index = (spec[:,0]  >= bin_i) & (spec[:,0]  < (bin_i+tol))
        bin_spec[i] = np.sum(spec[index ,2])
    
    return bin_spec

def load_spectra(file,mass_range,tol,df):

    mass_vec = np.arange(mass_range[0],mass_range[1],tol)

    mat_bin_vec = np.zeros((np.shape(df)[0],len(mass_vec)))
    labes_vec = []

    ct = 0
    for index, row in df.iterrows():
        #print(index, row['MSI name'], row['MSI pixel id'])
        #labes_vec.append(row['Annotations 2'])
        path = file + row['MSI name'] +"/spec_" + str(row['MSI pixel id']) + ".npy"

        spec = np.load(path)
        bin_spec = bin_ms(spec,mass_range,tol)
        mat_bin_vec[ct,:] = bin_spec
        print(ct)
        ct = ct +1
    mat_bin_vec = np.transpose(mat_bin_vec)
    return(mat_bin_vec)


# to change according to the sample
mass_range = [200,1400]
tol = 0.1
nb_classes = 2

df = pd.read_csv("/media/USB2/DL_MASS/DS3/Annot_table_reduce.csv",sep=",", header=0)


file = "/media/USB2/DL_MASS/DS3/MSI/centroid_data/param_1reduce/"
mat_bin_vec= load_spectra(file,mass_range,tol,df)
np.save(file+"mat_bin_vec", mat_bin_vec)

# %%
# rename
#/media/USB/DL_MASS/Dataset/DS/MSI/raw_data/S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv/#8.imzML and #8.ibd
#by
#/media/USB/DL_MASS/Dataset/DS/MSI/raw_data/S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv/S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv.imzML and S-2006-004769-2_Sec8_S2_lip_pos_20201203_dv.ibd

# %%
# create parameters folder: mkdir DS/parameters
# create parameters folder: mkdir DS/parameters/pre_processing

# %%
#create json param file for preprocessing 
mass_diff = np.genfromtxt("/media/USB/DL_MASS/Dataset/DS/mass_diff.csv")
mass_diff = mass_diff.tolist()
folder_path = "/media/USB/DL_MASS/Dataset/DS/"

dictionary ={
    "max_peaks": 2000,
    "mass_diff": mass_diff,
    "tolerance": 0.001,
    "mass range": [200, 1400],
    "msi_dir": folder_path+"MSI/raw_data/",
    "output_dir": folder_path+"MSI/centroid_data/",
    "file_type": "imzML",
    "annot_table":folder_path+"Annot_table_organs.csv"
}

json_object = json.dumps(dictionary,indent=4)

with open(folder_path +"parameters/pre_processing/param_1.json", "w") as outfile:
    outfile.write(json_object)
    
    
mass_diff = np.genfromtxt("/media/USB/DL_MASS/Dataset/DS/mass_diff.csv")
mass_diff = mass_diff.tolist()
folder_path = "/media/USB/DL_MASS/Dataset/DS/"

dictionary ={
    "max_peaks": 2000,
    "mass_diff": mass_diff,
    "tolerance": 0.001,
    "mass range": [200, 1400],
    "msi_dir": folder_path+"MSI/raw_data/",
    "output_dir": folder_path+"MSI/centroid_data/",
    "file_type": "imzML",
    "annot_table":folder_path+"Annot_table_bacteria.csv"
}

json_object = json.dumps(dictionary,indent=4)

with open(folder_path +"parameters/pre_processing/param_2.json", "w") as outfile:
    outfile.write(json_object)

# %%
#conda install -c bioconda pyimzml
#conda install -c conda-forge glob2

# %%
# command line for pre_processing 
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i "/media/USB/DL_MASS/Dataset/DS/parameters/pre_processing/param_1.json" &
nohup python "/home/user/Massconvnet/Massconvnet/MSI_preprocessing/Centroid_from_imzml.py" -i "/media/USB/DL_MASS/Dataset/DS/parameters/pre_processing/param_2.json" &

# %%
# create parameters folder: mkdir DS/parameters/network

# %%
folder_path = "--with_intensity"

dictionary ={
    "signal degradation": False,
    "only test": False,
    "only train": False,
    "intensity limitation param": 1,
    "mass shift param": 0,
    "spectral resolution param": 0,
    "random peaks removal param": 1,
    "edge index to remove": None,
    "Data augmentation": 0,
    "Annotation name": "Annotations",
    "training samples": "train",
    "kfold seed": 1,
    "kfold K": 0
}

json_object = json.dumps(dictionary,indent=4)

with open(folder_path +"parameters/network/param_1.json", "w") as outfile:
    outfile.write(json_object)

# %%
import os
import json
import numpy as np

# Define base folder
#folder_path = "./DS/"
folder_path = "/media/USB2/Massconvnet_data/"


# Build dictionary
param_dict ={
    "signal degradation": False,
    "only test": False,
    "only train": False,
    "intensity limitation param": 1,
    "mass shift param": 0,
    "spectral resolution param": 0,
    "random peaks removal param": 1,
    "edge index to remove": None,
    "Data augmentation": 0,
    "Annotation name": "Annotations",
    "training samples": "train",
    "kfold seed": 1,
    "kfold K": 0
}

# Save JSON
output_path = os.path.join(folder_path, "parameters", "network", "param_1.json")
os.makedirs(os.path.dirname(output_path), exist_ok=True)

with open(output_path, "w") as f:
    json.dump(param_dict, f, indent=4)

print(f"✅ Preprocessing parameter file saved to: {output_path}")
# Out:
# ✅ Preprocessing parameter file saved to: /media/USB2/Massconvnet_data/parameters/network/param_1.json

# %%
import pandas as pd
pd.read_csv("/media/USB2/Massconvnet_data/Annot_table/annot_table_mean_imsim_tol.csv")
# Out:
#    Unnamed: 0     MSI name  Crd X  Crd Y  origianl MSI pixel id  MSI pixel id  \
# 0           0  meanspectra      0      0                      0             0
# 1           1  meanspectra      0      0                      1             1
# 2           2  meanspectra      0      0                      2             2
# 3           3  meanspectra      0      0                      3             3
#
#    Annotations  selected row  train                MSI origin
# 0            1             1      0  pseudo_int_tol01_cosine6
# 1            1             1      0          pseudo_int_tol01
# 2            1             1      0  pseudo_int_tol03_cosine6
# 3            1             1      0          pseudo_int_tol03

# %%
#conda activate CALF-pytorch

# %%
python /home/user/Massconvnet/Massconvnet/src/main.py --dataset_path="/media/USB/DL_MASS/Dataset/DS/" --pre_process_param_name=param_1 --network_param_name=param_1 --with_masses --normalize
python /home/user/Massconvnet/Massconvnet/src/main.py --dataset_path="/media/USB/DL_MASS/Dataset/DS/" --pre_process_param_name=param_1 --network_param_name=param_2 --with_masses --normalize

# %%
### TODO
# 1) Replace the max pooling function by a global average function
# 2) From a trained model, return the predicted class for each sample in the annot_table 
# (add the prediction to the annot_table dataframe)
# 3) CAM implementation -> return the peak weight for each class
# 4) Return CAM weight for each sample of the annot_table dataframe

# %%
rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_pseudo01_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_pseudo03_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_pseudo05_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_spaceM_tol01_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_spaceM_tol03_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_spaceM_tol05_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_interactionfer_tol01_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_interactionfer_tol03_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_interactionfer_tol05_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python  /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_cellobiose_tol01_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_cellobiose_tol03_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/


rm -r /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet/src/main.py  --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/meanspectra_cellobiose_tol05_trainnoint5/
mkdir /media/USB2/DL_MASS/Dataset/DS/models/CAM_model/Testset/

# %%
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol01_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol05_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol05_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol05_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

# %%
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol05_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol05_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

# %%
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint5_temb/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 4
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint4_temb/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 3
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint3_temb/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 2
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint2_temb/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 1
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint1_temb/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_intensity --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint5_tembint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 4
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_intensity --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint4_tembint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 3
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_intensity --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint3_tembint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 2
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_intensity --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint2_tembint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 1
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_intensity --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint1_tembint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint5_tembint_meannoint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 4
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint4_tembint_meannoint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 3
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint3_tembint_meannoint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 2
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint2_tembint_meannoint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_intensity --with_masses --normalize --max_epochs 40 --random_state 1
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint1_tembint_meannoint/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

# %%
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol05_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol01_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol05_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol05_trainnoint5_fullnet/

rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol01 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol01_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol03 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol03_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol05 --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_tol --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol05_trainnoint5_fullnet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

# %%
rm -r /media/USB2/Massconvnet_data/models/CAM_output/

python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_pseudo_tol03_reducenet --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_reducenet --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

rm -r /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol03_trainnoint5_reducenet/
mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_pseudo_tol03_trainnoint5_reducenet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_spaceM_tol03_reducenet --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_reducenet --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

rm -r /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol03_trainnoint5_reducenet/
mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_spaceM_tol03_trainnoint5_reducenet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_cellobiose_tol03_reducenet --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_reducenet --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

rm -r /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol03_trainnoint5_reducenet/
mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_cellobiose_tol03_trainnoint5_reducenet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/


python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_interactionfer_tol03_reducenet --network_param_name=param_1 --with_masses --normalize --max_epochs 40 --random_state 5
python /home/user/Massconvnet/Massconvnet_2025/src/main.py --dataset_path="/media/USB2/Massconvnet_data//" --pre_process_param_name=param_mean_reducenet --network_param_name=param_1 --with_masses --normalize --cam_only --batch_size 1

rm -r /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol03_trainnoint5_reducenet/
mv /media/USB2/Massconvnet_data//models/CAM_output/ /media/USB2/Massconvnet_data/models/meanspectra_interactionfer_tol03_trainnoint5_reducenet/
rm -r /media/USB2/Massconvnet_data/models/CAM_output/
